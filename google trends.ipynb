# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
import glob

# %matplotlib inline

# %%
# headers = {
#     'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'
# }

# #url = f"https://trends.google.com/trends/explore?date=all&geo=US&q=doge"
# response = requests.get('https://trends.google.com/trends/explore?date=all&geo=US&q=doge', headers=headers)
# doc = BeautifulSoup(response.text)

# stuff = doc.find_all('div')
# stuff

# %%
# the above scraping attempt failed -- Google said I made too many requests :( 
# therefore, I just downloaded all the csv's manually

# %%
# this is how I combined them all into one csv:

# csv = glob.glob("*.csv")

# doge = pd.read_csv("doge meme.csv")
# doge.head()
# for c in csv:
#     mini_master = pd.read_csv(c) 
#     doge = doge.merge(mini_master, on='Region')

#doge.columns

# %%
#doge.to_csv("google_trends_master.csv", index=False)

# %%
google_trends = pd.read_csv("google_trends_master.csv")
google_trends
# Out:
#                   Region  doge_x  white guy blinking  spongegar  \
# 0                 Alaska     100                 NaN       67.0
# 1                Indiana      97                61.0       65.0
# 2             Washington      95                95.0       49.0
# 3                   Iowa      94                86.0       41.0
# 4                   Utah      93                33.0       59.0
# 5                 Nevada      91               100.0       65.0
# 6               Nebraska      89                88.0       41.0
# 7               Oklahoma      88                47.0       59.0
# 8              Wisconsin      88                56.0       55.0
# 9                Arizona      88                84.0       62.0
# 10                Oregon      85                50.0       38.0
# 11               Vermont      85                 NaN       31.0
# 12          Rhode Island      84                 NaN       56.0
# 13                Kansas      84                51.0       33.0
# ...
